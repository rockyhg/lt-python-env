# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = np.random.randn(1000)
plt.hist(x=data, bins=20)
# Out:
# (array([  2.,   0.,   3.,   4.,  13.,  24.,  43.,  79.,  99., 140., 146.,
#         130., 104.,  79.,  65.,  35.,  17.,   8.,   5.,   4.]),
#  array([-3.65617363, -3.3088364 , -2.96149917, -2.61416193, -2.2668247 ,
#         -1.91948747, -1.57215024, -1.22481301, -0.87747577, -0.53013854,
#         -0.18280131,  0.16453592,  0.51187316,  0.85921039,  1.20654762,
#          1.55388485,  1.90122208,  2.24855932,  2.59589655,  2.94323378,
#          3.29057101]),
#  <BarContainer object of 20 artists>)
